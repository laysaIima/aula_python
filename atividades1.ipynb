# %% [markdown]
# Exercício 1: Crie um programa que mostre na tela:

# %%
frase1 = "Eu estou aprendendo Python"
print(frase1)
# Out:
# Eu estou aprendendo Python

# %% [markdown]
# Exercício 2: Crie um programa que mostre:
# Meu nome é Maria
# Eu moro em Recife

# %%
nome = "Laysa"
cidade = "Goiânia"
print("Meu nome é", nome, "\nEu moro em", cidade)
# Out:
# Meu nome é Laysa
# Eu moro em Goiânia

# %% [markdown]
# Exercício 3: Crie duas variáveis: nome_do_aluno e idade_do_aluno.
# Depois mostre na tela algo assim: Meu nome é Ana e tenho 18 anos

# %%
nome_do_aluno = "Laysa"
idade_do_aluno = "28"
print("Meu nome é", nome_do_aluno, "\ne tenho", idade_do_aluno, "anos")
# Out:
# Meu nome é Laysa
# e tenho 28 anos

# %% [markdown]
# Exercício 4 (Desafio Extra)
# Crie três variáveis: cidade, estado e pais. E mostre: Eu moro em Salvador - BA, Brasil

# %%
cidade = "Goiânia "
estado = "- GO"
pais = " Brasil"
print("Eu moro em", cidade + estado + pais)
# Out:
# Eu moro em Goiânia - GO Brasil

# %% [markdown]
# Crie um programa que:
# 1. Pergunte o nome do aluno.
# 2. Pergunte a cidade onde ele mora.
# 3. Mostre a frase: Olá João, você mora em Curitiba

# %%
entrada = input("Digite seu nome:")
cidade = input("Qual cidade você mora?")
print("Olá",entrada,"você mora em",cidade)
# Out:
# Digite seu nome: Laysa
# Qual cidade você mora? Goiânia
# Olá Laysa você mora em Goiânia
